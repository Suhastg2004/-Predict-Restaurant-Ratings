# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/Dataset .csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#Checking for null/Nan values in the data
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#Checking the datatype of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#Encoding categorical values by one hot encoding
# Import necessary libraries
from sklearn.preprocessing import OneHotEncoder

# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Apply one-hot encoding
data_encoded = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# Display the first few rows of the encoded dataset
data_encoded.head()
# Out:
#    Restaurant ID  Country Code   Longitude   Latitude  Average Cost for two  \
# 0        6317637           162  121.027535  14.565443                  1100
# 1        6304287           162  121.014101  14.553708                  1200
# 2        6300002           162  121.056831  14.581404                  4000
# 3        6318506           162  121.056475  14.585318                  1500
# 4        6314302           162  121.057508  14.584450                  1500
#
#    Price range  Aggregate rating  Votes  Restaurant Name_#Dilliwaala6  \
# 0            3               4.8    314                         False
# 1            3               4.5    591                         False
# 2            4               4.4    270                         False
# 3            4               4.9    365                         False
# 4            4               4.8    229                         False
#
#    Restaurant Name_#InstaFreeze  ...  Rating color_Green  Rating color_Orange  \
# ...

# %%
x = np.array(data_encoded.drop('Aggregate rating',axis=1))
y = np.array(data_encoded['Aggregate rating'])
print("Features x shape:",x.shape)
print("Target y shape",y.shape)
# Out:
# Features x shape: (9551, 20828)
# Target y shape (9551,)

# %%
print('X values will look like',x[0])
print('X Shape',x.shape)
print('Shape of x[i]:',x[1].shape)
# Out:
# X values will look like [6317637 162 121.027535 ... False False False]
# X Shape (9551, 20828)
# Shape of x[i]: (20828,)

# %%
print('y values will look like',y[0])
print('y Shape',y.shape)
# Out:
# y values will look like 4.8
# y Shape (9551,)

# %%
#Splitting data into test and trainign data
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2) #test_size = 0.2 indicates that 20% of the data has been used for testing
print('X_train shape:',x_train.shape)
print('y_train shape:',y_train.shape)
print('X_test shape:',x_test.shape)
print('y_test shape:',y_test.shape)
# Out:
# X_train shape: (7640, 20828)
# y_train shape: (7640,)
# X_test shape: (1911, 20828)
# y_test shape: (1911,)

# %%
def compute_cost(w,b,x,y):
    m = x.shape[0] #number of training example
    total_cost = 0
    f_wb = 0
    for i in range(m):
        f_wb = np.dot(w,x[i]) + b
        total_cost += (f_wb - y[i])**2

    total_cost = total_cost/(2*m)
    return total_cost

# %%
def compute_gradient(w, b, x, y):
    m = x.shape[0]
    n = x.shape[1]  # Number of features
    dj_dw = np.zeros(n)
    dj_db = 0
    for i in range(m):
        f_wb = np.dot(w, x[i]) + b
        dj_dwi = (f_wb - y[i]) * x[i]
        dj_dbi = (f_wb - y[i])

        dj_dw += dj_dwi
        dj_db += dj_dbi
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    return dj_dw, dj_db

# %%
import math
def gradient_descent(x, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters):
    """
    Performs batch gradient descent to learn theta. Updates theta by taking
    num_iters gradient steps with learning rate alpha

    Args:
      x :    (ndarray): Shape (m,)
      y :    (ndarray): Shape (m,)
      w_in, b_in : (scalar) Initial values of parameters of the model
      cost_function: function to compute cost
      gradient_function: function to compute the gradient
      alpha : (float) Learning rate
      num_iters : (int) number of iterations to run gradient descent
    Returns
      w : (ndarray): Shape (1,) Updated values of parameters of the model after
          running gradient descent
      b : (scalar)                Updated value of parameter of the model after
          running gradient descent
    """

    # number of training examples
    m = len(x)

    # An array to store cost J and w's at each iteration — primarily for graphing later
    J_history = []
    w_history = []
    w = w_in
    b = b_in

    for i in range(num_iters):

        # Calculate the gradient and update the parameters
        dj_dw, dj_db = np.zeros_like(w_in), 0.0 # Initialize gradients
        for j in range(m): # Iterate over each training example
            dj_dwi, dj_dbi = gradient_function(x[j], y[j], w, b) # Calculate gradient for a single example
            dj_dw += dj_dwi
            dj_db += dj_dbi
        dj_dw = dj_dw / m # Average the gradients
        dj_db = dj_db / m

        # Update Parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion
            cost =  cost_function(x, y, w, b)
            J_history.append(cost)

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters/10) == 0:
            w_history.append(w)
            print(f"Iteration {i:4}: Cost {float(J_history[-1]):8.2f}   ")

    return w, b, J_history, w_history #return w and J,w history for graphing

def compute_gradient(w, b, x, y): # Modified to handle single data points
    # x is now a single data point, not the entire training set
    f_wb = np.dot(w, x) + b
    dj_dw = (f_wb - y) * x
    dj_db = (f_wb - y)
    return dj_dw, dj_db

# %%
n_features = x_train.shape[1]
initial_w = np.zeros(n_features)
initial_b = 0.0
# some gradient descent settings
iterations = 1500
alpha = 0.01

w,b,_,_ = gradient_descent(x_train ,y_train, initial_w, initial_b,
                     compute_cost, compute_gradient, alpha, iterations)
print("w,b found by gradient descent:", w, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-107eaabf0b91> in <cell line: 8>()
#       6 alpha = 0.01
#       7
# ----> 8 w,b,_,_ = gradient_descent(x_train ,y_train, initial_w, initial_b,
#       9                      compute_cost, compute_gradient, alpha, iterations)
#      10 print("w,b found by gradient descent:", w, b)
#
# <ipython-input-25-d9834230ff44> in gradient_descent(x, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters)
#      46         # Save cost J at each iteration
#      47         if i<100000:      # prevent resource exhaustion
# ---> 48             cost =  cost_function(x, y, w, b)
#      49             J_history.append(cost)
#      50
#
# <ipython-input-11-8b4982fb044d> in compute_cost(w, b, x, y)
#       4     f_wb = 0
#       5     for i in range(m):
# ----> 6         f_wb = np.dot(w,x[i]) + b
# ...
